# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Practice Questions for numpy

# %% [markdown]
# 1. Define two custom numpy arrays, say A and B. Generate two new numpy arrays by stacking A and B vertically and horizontally.

# %%
A = np.array([1, 2, 3, 4, 5])
B = np.array([5, 6, 7, 8, 9])
vertical = np.concatenate([A.reshape(1, len(A)), B.reshape(1, len(B))], axis=0)
horizontal = np.concatenate([A, B])
print(vertical)
print(horizontal)
# Out:
# [[1 2 3 4 5]
#  [5 6 7 8 9]]
# [1 2 3 4 5 5 6 7 8 9]

# %% [markdown]
# 2. Find common elements between A and B.

# %%
np.intersect1d(A, B)
# Out:
# array([5])

# %% [markdown]
# 3. Extract all numbers from A which are within a specific range. eg between 5 and 10.

# %%
mask = np.where(A<3)
A[mask]
# Out:
# array([1, 2])

# %% [markdown]
# 4. Filter the rows of iris_2d that has petallength (3rd column) > 1.5 and sepallength (1st column) < 5.0

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])

# %%
rows0 = np.where(iris_2d[:,0]<5)
ret = iris_2d[rows0]
rows1 = np.where(ret[:,2]>1.5)
ret = ret[rows1]
ret
# Out:
# array([[4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.9, 2.5, 4.5, 1.7]])

# %% [markdown]
# Optional: Find the mean of a numeric column grouped by a categorical column in a 2D numpy array

# %%
## Optional Practice Question

#Find the mean of a numeric column grouped by a categorical column in a 2D numpy array

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = np.genfromtxt(url, delimiter=',', dtype='object')
names = ('sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'species')


numeric_column = iris[:, 1].astype('float')  # sepalwidth
grouping_column = iris[:, 4]  # species

output = []
"""Your code goes here"""
output = numeric_column.mean()

output
# Out:
# 3.0540000000000003

# %% [markdown]
# ## Practice Questions for Pandas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# 1. From df filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).

# %%
rows = [20*i for i in range(df.shape[0]//20+1)]
df.iloc[rows][['Manufacturer', 'Model', 'Type']]
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# 2. Replace missing values in Min.Price and Max.Price columns with their respective mean.

# %%
df['Min.Price'] = df['Min.Price'].fillna(df['Min.Price'].mean())
df['Max.Price'] = df['Max.Price'].fillna(df['Max.Price'].mean())
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small  12.900000   15.9  18.800000      25.0
# 1           NaN   Legend  Midsize  29.200000   33.9  38.700000      18.0
# 2          Audi       90  Compact  25.900000   29.1  32.300000      20.0
# 3          Audi      100  Midsize  17.118605   37.7  44.600000      19.0
# 4           BMW     535i  Midsize  17.118605   30.0  21.459091      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van  16.600000   19.7  22.700000      17.0
# 89   Volkswagen   Passat  Compact  17.600000   20.0  22.400000      21.0
# 90   Volkswagen  Corrado   Sporty  22.900000   23.3  23.700000      18.0
# 91        Volvo      240  Compact  21.800000   22.7  23.500000      21.0
# 92          NaN      850  Midsize  24.800000   26.7  28.500000      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# 3. How to get the rows of a dataframe with row sum > 100?

# %%
df3 = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df3.loc[df3.sum(axis=1)>100]
# Out:
#     0   1   2   3
# 3  36  18  36  32
# 4  32  39  21  27
# 6  31  34  37  20
# 8  37  23  38  33
# 9  23  35  29  29
